# %% [markdown]
# # Stock Prediction in Python

# %%
# %matplotlib inline
import pandas as pd

pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import datetime
import seaborn as sb
import sklearn.linear_model as lm
from sklearn.model_selection import train_test_split
import sklearn as sk
sb.set_style("whitegrid")

# %%
start = datetime.datetime(2014,1,1)
end = datetime.datetime.today()
NVDA = web.DataReader("NVDA",'google', start, end)
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-65-067478cd9449> in <module>()
#       1 start = datetime.datetime(2014,1,1)
#       2 end = datetime.datetime.today()
# ----> 3 NVDA = web.DataReader("NVDA",'google', start, end)
#
# /anaconda/lib/python3.5/site-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     135                                  chunksize=25,
#     136                                  retry_count=retry_count, pause=pause,
# --> 137                                  session=session).read()
#     138
#     139     elif data_source == "enigma":
#
# /anaconda/lib/python3.5/site-packages/pandas_datareader/base.py in read(self)
#     179         if isinstance(self.symbols, (compat.string_types, int)):
#     180             df = self._read_one_data(self.url,
# ...

# %%
NVDA["Date"] = NVDA.index
NVDA.head(4)
# Out:
#              Open   High    Low  Close    Volume       Date
# Date
# 2014-01-02  15.92  15.98  15.72  15.86   6502296 2014-01-02
# 2014-01-03  15.89  15.92  15.62  15.67   6483288 2014-01-03
# 2014-01-06  15.83  16.00  15.68  15.88  10237417 2014-01-06
# 2014-01-07  16.04  16.20  15.92  16.14   8332170 2014-01-07

# %%
NVDA.dtypes
# Out:
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume             int64
# Date      datetime64[ns]
# dtype: object

# %%
NVDA.Open.plot()

# %%
fig, ax = plt.subplots()
#ax.plot(NVDA.Open, NVDA.Close)
ax.scatter(x=NVDA.Open, y=NVDA.Close)
ax.set(title = "NVDA Open vs. Close",
      ylabel='NVDA Close',
      xlabel='NVDA Open')

# %%
NVDA.index
# Out:
# DatetimeIndex(['2014-01-02', '2014-01-03', '2014-01-06', '2014-01-07',
#                '2014-01-08', '2014-01-09', '2014-01-10', '2014-01-13',
#                '2014-01-14', '2014-01-15',
#                ...
#                '2017-06-09', '2017-06-12', '2017-06-13', '2017-06-14',
#                '2017-06-15', '2017-06-16', '2017-06-19', '2017-06-20',
#                '2017-06-21', '2017-06-22'],
#               dtype='datetime64[ns]', name=u'Date', length=875, freq=None)

# %%
train, test = train_test_split(NVDA, test_size = .30, random_state = 1010)

regr = lm.LinearRegression()

# %%
test.shape
# Out:
# (262, 5)

# %% [markdown]
# <hr>

# %% [markdown]
# <hr>

# %% [markdown]
# <hr>

# %%
### Using Stocker for stock market analysis

from stocker import Stocker

# %%
TER = Stocker("TER")
# Out:
# TER Stocker Initialized. Data covers 1987-03-11 to 2018-03-27.
# /Users/NNK/Documents/project/PyTrade/stocker.py:70: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   self.starting_price = float(self.stock.ix[0, 'Adj. Open'])
# /Users/NNK/Documents/project/PyTrade/stocker.py:73: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   self.most_recent_price = float(self.stock.ix[len(self.stock) - 1, 'y'])

# %%
TER_History = TER.stock
TER_History.tail()
# Out:
#            Date   Open   High    Low  Close     Volume  Ex-Dividend  \
# 7820 2018-03-21  49.15  50.29  49.05  49.50  1907062.0          0.0
# 7821 2018-03-22  48.63  49.12  47.27  47.72  3017547.0          0.0
# 7822 2018-03-23  47.75  48.11  45.64  45.65  2912567.0          0.0
# 7823 2018-03-26  47.30  47.70  46.52  47.70  1901407.0          0.0
# 7824 2018-03-27  48.01  48.08  45.40  45.76  2026797.0          0.0
#
#       Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume  \
# 7820          1.0      49.15      50.29     49.05       49.50    1907062.0
# 7821          1.0      48.63      49.12     47.27       47.72    3017547.0
# 7822          1.0      47.75      48.11     45.64       45.65    2912567.0
# 7823          1.0      47.30      47.70     46.52       47.70    1901407.0
# 7824          1.0      48.01      48.08     45.40       45.76    2026797.0
#
#              ds      y  Daily Change
# 7820 2018-03-21  49.50          0.35
# ...

# %%
TER.stock.iloc[1,0]
# Out:
# Timestamp('1987-03-12 00:00:00')

# %%
TER.stock.dtypes
# Out:
# Date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Volume                 float64
# Ex-Dividend            float64
# Split Ratio            float64
# Adj. Open              float64
# Adj. High              float64
# Adj. Low               float64
# Adj. Close             float64
# Adj. Volume            float64
# ds              datetime64[ns]
# y                      float64
# Daily Change           float64
# dtype: object

# %%
TER.plot_stock(stats=['Daily Change'])
# Out:
# /Users/NNK/Documents/project/PyTrade/stocker.py:178: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   trim_df = df[(df['Date'] >= start_date.date()) &
# /Users/NNK/Documents/project/PyTrade/stocker.py:179: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   (df['Date'] <= end_date.date())]
# /Users/NNK/Documents/project/PyTrade/stocker.py:249: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# ...

# %%
TER.plot_stock(start_date = '2000-01-03',  end_date = '2018-01-16',
                     stats = ['Daily Change', 'Adj. Volume'],  plot_type='pct')
# Out:
# /Users/NNK/Documents/project/PyTrade/stocker.py:178: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   trim_df = df[(df['Date'] >= start_date.date()) &
# /Users/NNK/Documents/project/PyTrade/stocker.py:179: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   (df['Date'] <= end_date.date())]
# /Users/NNK/Documents/project/PyTrade/stocker.py:249: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# ...

# %%
TER.buy_and_hold(start_date='2011-03-13', 
                       end_date='2018-01-16', nshares=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-3ce5b25794c8> in <module>()
#       1 TER.buy_and_hold(start_date='2011-03-13',
# ----> 2                        end_date='2018-01-16', nshares=100)
#
# ~/Documents/project/PyTrade/stocker.py in buy_and_hold(self, start_date, end_date, nshares)
#     329
#     330         # Find starting and ending price of stock
# --> 331         start_price = float(self.stock[self.stock['Date'] == start_date]['Adj. Open'])
#     332         end_price = float(self.stock[self.stock['Date'] == end_date]['Adj. Close'])
#     333
#
# /anaconda/lib/python3.5/site-packages/pandas/core/series.py in wrapper(self)
#     116             return converter(self.iloc[0])
#     117         raise TypeError("cannot convert the series to "
# --> 118                         "{0}".format(str(converter)))
#     119
#     120     return wrapper
#
# ...

# %% [markdown]
# ### Implementing FB Prophet Model

# %%
model, model_data = TER.create_prophet_model(days=180)
# Out:
# /Users/NNK/Documents/project/PyTrade/stocker.py:444: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   stock_history = self.stock[self.stock['Date'] > (self.max_date - pd.DateOffset(years = self.training_years)).date()]
# /anaconda/lib/python3.5/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# /Users/NNK/Documents/project/PyTrade/stocker.py:458: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# ...

# %% [markdown]
# ## <><><><><><><><><><><><><><><><><><><><><><><><><><><><>

# %% [markdown]
# ## Just fbprophet model alone without Stocker

# %% [markdown]
# ## <><><><><><><><><><><><><><><><><><><><><><><><><><><><>

# %%
import fbprophet
